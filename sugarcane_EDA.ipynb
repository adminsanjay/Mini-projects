# %% [markdown]
# <a href="https://colab.research.google.com/github/adminsanjay/Mini-projects/blob/main/sugarcane_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/content/List of Countries by Sugarcane Production.csv")
df
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America       768.678.382
# 1             1      India           Asia       348.448.000
# 2             2      China           Asia       123.059.739
# 3             3   Thailand           Asia        87.468.496
# 4             4   Pakistan           Asia        65.450.704
# ..          ...        ...            ...               ...
# 98           98    Lebanon           Asia                97
# 99           99   Djibouti         Africa                53
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3.668,531        10.226.205             75.167,5
# 1                       260721         4.950.000             70.393,5
# ...

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.shape
# Out:
# (103, 7)

# %% [markdown]
# Data Cleaning

# %%
df['Production (Tons)'] = df['Production (Tons)'].str.replace('.', '')
df['Production per Person (Kg)'] = df['Production per Person (Kg)'].str.replace('.', '').str.replace(',', '.')
df['Acreage (Hectare)'] = df['Acreage (Hectare)'].str.replace(".","")
df['Yield (Kg / Hectare)'] = df['Yield (Kg / Hectare)'].str.replace('.', '').str.replace(',', '.')

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
df.rename(columns={'Production (Tons)': 'Production(tons)'}, inplace=True)
df.rename(columns={'Production per Person (Kg)': 'Production_per_person(kg)'}, inplace=True)
df.rename(columns={'Acreage (Hectare)': 'Acreage(hectare)'}, inplace=True)
df.rename(columns={'Yield (Kg / Hectare)': 'Yield(kg/hectare)'}, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production(tons)  \
# 0           0    Brazil  South America        768678382
# 1           1     India           Asia        348448000
# 2           2     China           Asia        123059739
# 3           3  Thailand           Asia         87468496
# 4           4  Pakistan           Asia         65450704
#
#   Production_per_person(kg) Acreage(hectare) Yield(kg/hectare)
# 0                  3668.531         10226205           75167.5
# 1                    260721          4950000           70393.5
# 2                     88287          1675215           73459.1
# 3                  1264.303          1336575           65442.2
# 4                    324219          1130820             57879

# %%
df.isna().sum()
# Out:
# Unnamed: 0                   0
# Country                      0
# Continent                    0
# Production(tons)             0
# Production_per_person(kg)    0
# Acreage(hectare)             1
# Yield(kg/hectare)            1
# dtype: int64

# %%
df[df['Acreage(hectare)'].isna()]
# Out:
#     Unnamed: 0   Country Continent Production(tons) Production_per_person(kg)  \
# 99          99  Djibouti    Africa               53                        51
#
#    Acreage(hectare) Yield(kg/hectare)
# 99              NaN               NaN

# %%
df.dropna().reset_index()
# Out:
#      index  Unnamed: 0    Country      Continent Production(tons)  \
# 0        0           0     Brazil  South America        768678382
# 1        1           1      India           Asia        348448000
# 2        2           2      China           Asia        123059739
# 3        3           3   Thailand           Asia         87468496
# 4        4           4   Pakistan           Asia         65450704
# ..     ...         ...        ...            ...              ...
# 97      97          97      Spain         Europe              394
# 98      98          98    Lebanon           Asia               97
# 99     100         100  Singapore           Asia               50
# 100    101         101      Samoa        Oceania               12
# 101    102         102      Syria           Asia                1
#
#     Production_per_person(kg) Acreage(hectare) Yield(kg/hectare)
# 0                    3668.531         10226205           75167.5
# ...

# %%
df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
df.head()
# Out:
#     Country      Continent Production(tons) Production_per_person(kg)  \
# 0    Brazil  South America        768678382                  3668.531
# 1     India           Asia        348448000                    260721
# 2     China           Asia        123059739                     88287
# 3  Thailand           Asia         87468496                  1264.303
# 4  Pakistan           Asia         65450704                    324219
#
#   Acreage(hectare) Yield(kg/hectare)
# 0         10226205           75167.5
# 1          4950000           70393.5
# 2          1675215           73459.1
# 3          1336575           65442.2
# 4          1130820             57879

# %%
df.dtypes
# Out:
# Country                      object
# Continent                    object
# Production(tons)             object
# Production_per_person(kg)    object
# Acreage(hectare)             object
# Yield(kg/hectare)            object
# dtype: object

# %%
df['Production(tons)'] = df['Production(tons)'].astype(float)
df['Production_per_person(kg)'] = df['Production_per_person(kg)'].astype(float)
df['Acreage(hectare)'] = df['Acreage(hectare)'].astype(float)
df['Yield(kg/hectare)'] = df['Yield(kg/hectare)'].astype(float)
df.dtypes
# Out:
# Country                       object
# Continent                     object
# Production(tons)             float64
# Production_per_person(kg)    float64
# Acreage(hectare)             float64
# Yield(kg/hectare)            float64
# dtype: object

# %%
df.nunique()
# Out:
# Country                      103
# Continent                      6
# Production(tons)             103
# Production_per_person(kg)    102
# Acreage(hectare)             101
# Yield(kg/hectare)            102
# dtype: int64

# %% [markdown]
# ###Univariate Analysis

# %%
df.head()
# Out:
#     Country      Continent  Production(tons)  Production_per_person(kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(hectare)  Yield(kg/hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %% [markdown]
# **How many countries produce sugarcan from each continent?**

# %%
df['Continent'].value_counts()
# Out:
# Continent
# Africa           39
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df['Continent'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Continent'>

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.distplot(df['Production(tons)'])
plt.subplot(2,2,2)
sns.distplot(df['Production_per_person(kg)'])
plt.subplot(2,2,3)
sns.distplot(df['Acreage(hectare)'])
plt.subplot(2,2,4)
sns.distplot(df['Yield(kg/hectare)'])
# Out:
# /tmp/ipykernel_1451/1574465503.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Production(tons)'])
# /tmp/ipykernel_1451/1574465503.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Production_per_person(kg)'])
# ...

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(df['Production(tons)'])
plt.subplot(2,2,2)
sns.boxplot(df['Production_per_person(kg)'])
plt.subplot(2,2,3)
sns.boxplot(df['Acreage(hectare)'])
plt.subplot(2,2,4)
sns.boxplot(df['Yield(kg/hectare)'])
# Out:
# <Axes: ylabel='Yield(kg/hectare)'>

# %%
df.describe()
# Out:
#        Production(tons)  Production_per_person(kg)  Acreage(hectare)  \
# count      1.030000e+02                 103.000000      1.020000e+02
# mean       1.832407e+07              111856.305311      2.498981e+05
# std        8.379760e+07              176134.928689      1.137003e+06
# min        1.000000e+00                   0.000000      0.000000e+00
# 25%        4.298850e+04                3364.869000      1.104000e+03
# 50%        1.422432e+06               25481.000000      1.655800e+04
# 75%        6.145648e+06              144004.500000      8.047400e+04
# max        7.686784e+08              951087.000000      1.022620e+07
#
#        Yield(kg/hectare)
# count         102.000000
# mean        52628.078431
# std         30504.676683
# min            10.000000
# 25%         29072.025000
# 50%         54108.950000
# 75%         73282.700000
# max        129049.300000

# %% [markdown]
# ###Bivariate analysis

# %%
df.head()
# Out:
#     Country      Continent  Production(tons)  Production_per_person(kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(hectare)  Yield(kg/hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %% [markdown]
# **How many countries produce sugarcan from each continent?**

# %%
df_new = df[["Country","Production(tons)"]].set_index("Country")
df_new
# Out:
#            Production(tons)
# Country
# Brazil          768678382.0
# India           348448000.0
# China           123059739.0
# Thailand         87468496.0
# Pakistan         65450704.0
# ...                     ...
# Lebanon                97.0
# Djibouti               53.0
# Singapore              50.0
# Samoa                  12.0
# Syria                   1.0
#
# [103 rows x 1 columns]

# %%
df_new["Production(tons)_percent"]=df_new["Production(tons)"]*100/df_new["Production(tons)"].sum()
df_new
# Out:
#            Production(tons)  Production(tons)_percent
# Country
# Brazil          768678382.0              4.072728e+01
# India           348448000.0              1.846200e+01
# China           123059739.0              6.520138e+00
# Thailand         87468496.0              4.634389e+00
# Pakistan         65450704.0              3.467809e+00
# ...                     ...                       ...
# Lebanon                97.0              5.139401e-06
# Djibouti               53.0              2.808126e-06
# Singapore              50.0              2.649176e-06
# Samoa                  12.0              6.358022e-07
# Syria                   1.0              5.298352e-08
#
# [103 rows x 2 columns]

# %%
df_new['Production(tons)_percent'].plot(kind="pie",subplots=True,figsize=(10,10))
# Out:
# array([<Axes: ylabel='Production(tons)_percent'>], dtype=object)

# %%
df_new['Production(tons)'].head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
ax = sns.barplot(data=df.head(10),x="Country",y="Production(tons)")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# /tmp/ipykernel_1451/4230702923.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# [Text(0, 0, 'Brazil'),
#  Text(1, 0, 'India'),
#  Text(2, 0, 'China'),
#  Text(3, 0, 'Thailand'),
#  Text(4, 0, 'Pakistan'),
#  Text(5, 0, 'Mexico'),
#  Text(6, 0, 'Colombia'),
#  Text(7, 0, 'Australia'),
#  Text(8, 0, 'Guatemala'),
#  Text(9, 0, 'United States of America')]

# %% [markdown]
# **Which country has highest land?**

# %%
df_acr = df.sort_values(by="Acreage(hectare)",ascending=False)
ax = sns.barplot(data=df_acr.head(10),x="Country",y="Acreage(hectare)")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# /tmp/ipykernel_1451/2225911452.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# [Text(0, 0, 'Brazil'),
#  Text(1, 0, 'India'),
#  Text(2, 0, 'China'),
#  Text(3, 0, 'Thailand'),
#  Text(4, 0, 'Pakistan'),
#  Text(5, 0, 'Mexico'),
#  Text(6, 0, 'Indonesia'),
#  Text(7, 0, 'Australia'),
#  Text(8, 0, 'Cuba'),
#  Text(9, 0, 'Colombia')]

# %% [markdown]
# **Which country has highest yield per hectare?**

# %%
df_hec = df.sort_values(by="Yield(kg/hectare)",ascending=False)
ax = sns.barplot(data=df_hec.head(10),x="Country",y="Yield(kg/hectare)")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# /tmp/ipykernel_1451/967132164.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# [Text(0, 0, 'Guatemala'),
#  Text(1, 0, 'Senegal'),
#  Text(2, 0, 'Egypt'),
#  Text(3, 0, 'Peru'),
#  Text(4, 0, 'Malawi'),
#  Text(5, 0, 'Chad'),
#  Text(6, 0, 'Zambia'),
#  Text(7, 0, 'Burkina Faso'),
#  Text(8, 0, 'Swaziland'),
#  Text(9, 0, 'Nicaragua')]

# %% [markdown]
# **Correlation**

# %%
df.head()
# Out:
#     Country      Continent  Production(tons)  Production_per_person(kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(hectare)  Yield(kg/hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %%
df_new = df[["Production(tons)","Production_per_person(kg)","Acreage(hectare)","Yield(kg/hectare)"]]
df_new.corr()
# Out:
#                            Production(tons)  Production_per_person(kg)  \
# Production(tons)                   1.000000                   0.016341
# Production_per_person(kg)          0.016341                   1.000000
# Acreage(hectare)                   0.997550                   0.012557
# Yield(kg/hectare)                  0.132812                   0.017999
#
#                            Acreage(hectare)  Yield(kg/hectare)
# Production(tons)                   0.997550           0.132812
# Production_per_person(kg)          0.012557           0.017999
# Acreage(hectare)                   1.000000           0.113433
# Yield(kg/hectare)                  0.113433           1.000000

# %%
sns.heatmap(df_new.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **Do countries with highest land produce more sugarcane?**

# %%
sns.scatterplot(data=df,x="Acreage(hectare)",y="Production(tons)")
# Out:
# <Axes: xlabel='Acreage(hectare)', ylabel='Production(tons)'>

# %% [markdown]
# **Do countries which yield more sugarcane per hectare produce more sugarcane?**

# %%
sns.scatterplot(data=df,x="Yield(kg/hectare)",y="Production(tons)")
# Out:
# <Axes: xlabel='Yield(kg/hectare)', ylabel='Production(tons)'>

# %% [markdown]
# ###Analysis for continent

# %%
df_cont = df.groupby("Continent").sum()
df_cont
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production(tons)  Production_per_person(kg)  Acreage(hectare)  \
# Continent
# Africa               89681525.0                2332687.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# ...

# %% [markdown]
# Which continent has max sugarcane?

# %%
df['Continent'].value_counts()
# Out:
# Continent
# Africa           39
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df_cont['Production(tons)'].sort_values(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %%
df_cont['Acreage(hectare)'].sort_values(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# **Do no of countries in continent effects production of sugarcane?**

# %%
df_cont['no of countries'] = df['Continent'].value_counts()
df_cont_sorted = df_cont.sort_values(by='no of countries')
cont_names_sorted = df_cont_sorted.index.to_list()
sns.lineplot(data=df_cont_sorted, x="no of countries", y="Production(tons)")
plt.xticks(df_cont_sorted["no of countries"], cont_names_sorted, rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x7eb117b210d0>,
# ...
#  [Text(2, 0, 'Europe'),
#   Text(4, 0, 'Oceania'),
#   Text(11, 0, 'South America'),
#   Text(22, 0, 'North America'),
#   Text(25, 0, 'Asia'),
#   Text(39, 0, 'Africa')])

# %% [markdown]
# **Production distribution by continent**

# %%
df_cont['Production(tons)'].plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='Production(tons)'>

# %% [markdown]
# **Continent correlation**

# %%
df_cont.head(2)
# Out:
#                                                      Country  \
# Continent
# Africa     EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia       IndiaChinaThailandPakistanIndonesiaPhilippines...
#
#            Production(tons)  Production_per_person(kg)  Acreage(hectare)  \
# Continent
# Africa           89681525.0                2332687.293         1439089.0
# Asia            721930425.0                1857769.303        10608319.0
#
#            Yield(kg/hectare)  no of countries
# Continent
# Africa             2142107.5               39
# Asia               1171871.4               25

# %%
df_cont_new = df_new[["Production(tons)","Production_per_person(kg)","Acreage(hectare)","Yield(kg/hectare)"]]
df_cont_new.corr()
# Out:
#                            Production(tons)  Production_per_person(kg)  \
# Production(tons)                   1.000000                   0.016341
# Production_per_person(kg)          0.016341                   1.000000
# Acreage(hectare)                   0.997550                   0.012557
# Yield(kg/hectare)                  0.132812                   0.017999
#
#                            Acreage(hectare)  Yield(kg/hectare)
# Production(tons)                   0.997550           0.132812
# Production_per_person(kg)          0.012557           0.017999
# Acreage(hectare)                   1.000000           0.113433
# Yield(kg/hectare)                  0.113433           1.000000
